# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../../RC4/z1_z2.txt", sep = ",")

# %%
df.head()
# Out:
#    s        z1        z2
# 0  0  0.003998  0.007690
# 1  1  0.003769  0.003998
# 2  2  0.003983  0.004135
# 3  3  0.003372  0.004028
# 4  4  0.003723  0.004166

# %%
# We are just trying to plot the distribution of z1 and z2
# This exercise just tells how biased the fir

s, z1, z2 = df['s'].tolist(), df['z1'].tolist(), df['z2'].tolist()
plt.plot(s, z1)
plt.xlabel('number')
plt.ylabel('probability')
plt.savefig('z1.png')

# %%
plt.plot(s, z2)
plt.xlabel('number')
plt.ylabel('probability')
plt.savefig('z2.png')
